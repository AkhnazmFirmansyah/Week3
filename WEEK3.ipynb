# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=4e0b59fc102fdbb561a08a6f8469d2f3b87ba47f1d8c66cfbe32dbe9e17a0065
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
# !mkdir -p /resources/data
# !wget -O /resources/data/Example1.txt https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Out:
# --2024-09-12 07:14:12--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘/resources/data/Example1.txt’
#
# /resources/data/Exa 100%[===================>]      45  --.-KB/s    in 0s
#
# 2024-09-12 07:14:12 (15.0 MB/s) - ‘/resources/data/Example1.txt’ saved [45/45]

# %%
# !mkdir -p TesBiodata

# %% [markdown]
# **Weekly Exercise 1** <p>1<p>

# %%
with open('TesBiodata.txt', 'w') as writefile:
    writefile.write("Nama   : Akhnaz Malik Firmansyah\n")
    writefile.write("Prodi  : S1 Teknologi Informasi\n")
    writefile.write("NPM    : 2440506072\n")
    writefile.write("Alamat : Desa Pakis\n")
    writefile.write("Hobi   : Membaca Komik\n")
    writefile.write("Email  : akhnazmfirmansyah@gmail.com\n")

# %%
with open('TesBiodata.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Nama   : Akhnaz Malik Firmansyah
# Prodi  : S1 Teknologi Informasi
# NPM    : 2440506072
# Alamat : Desa Pakis
# Hobi   : Membaca Komik
# Email  : akhnazmfirmansyah@gmail.com

# %% [markdown]
# 2

# %%
with open('TesBiodata.txt', 'r') as bio:
    c = bio.readlines ()
    print(c[0])
    print(c[1])
    print(c[5])
# Out:
# Nama   : Akhnaz Malik Firmansyah
#
# Prodi  : S1 Teknologi Informasi
#
# Email  : akhnazmfirmansyah@gmail.com

# %% [markdown]
# 3

# %%
with open ('TesBiodata.txt', 'r') as bio:
    c = bio.readlines ()
    print(c[0])
    print(c[2])
    print(c[1])
    print(c[3])
# Out:
# Nama   : Akhnaz Malik Firmansyah
#
# NPM    : 2440506072
#
# Prodi  : S1 Teknologi Informasi
#
# Alamat : Desa Pakis

# %%
with open('Biodata.txt', 'w') as writefile:
    writefile.write ('  ')

# %%
with open ('TesBiodata.txt', 'r') as bio:
    c = bio.readlines ()
    print(c[0])
    print(c[2])
    print(c[1])
    print(c[3])
# Out:
# Nama   : Akhnaz Malik Firmansyah
#
# NPM    : 2440506072
#
# Prodi  : S1 Teknologi Informasi
#
# Alamat : Desa Pakis

# %%
with open('TesBiodata.txt', 'r') as readfile:
    with open('Biodata.txt', 'w') as writefile:
        for line in readfile:
            writefile.write(line)

# %%
with open('Biodata.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Nama   : Akhnaz Malik Firmansyah
# Prodi  : S1 Teknologi Informasi
# NPM    : 2440506072
# Alamat : Desa Pakis
# Hobi   : Membaca Komik
# Email  : akhnazmfirmansyah@gmail.com

# %% [markdown]
# **Weekly Exercise 2**<p> Perbaiki script hingga tak muncul error

# %%
print("Selamat Datang di Toko Maju Jaya")
print("Senin, 4 September 2023    13.05\n")
print("DAFTAR BELANJA:")
item1 = 'Sabun'
item2 = 'Shampo'
item3 = 'Mie Instant'
item4 = 'Detergen'
harga1 = 10000
harga2 = 15000
harga3 =  5000
harga4 = 17500

total = harga1+harga2+harga3+harga4

print(item1,  "        = Rp",  harga1)
print(item2,  "       = Rp",  harga2)
print(item3,  "  = Rp",  harga3)
print(item4,  "     = Rp",  harga4)
print("\nTotal         = Rp", total)

with open('Kuitansi.txt', 'w') as writefile:
    writefile.write("Selamat Datang di Toko Maju Jaya\n")
    writefile.write("Kuitansi - 4 September 2023\n")
    writefile.write(item1 + " = Rp " + str(harga1) + "\n")
    writefile.write(item2 + " = Rp " + str(harga2) + "\n")
    writefile.write(item3 + " = Rp " + str(harga3) + "\n")
    writefile.write(item4 + " = Rp " + str(harga4) + "\n")
    writefile.write("Total Belanja = Rp " + str(total))
# Out:
# Selamat Datang di Toko Maju Jaya
# Senin, 4 September 2023    13.05
#
# DAFTAR BELANJA:
# Sabun         = Rp 10000
# Shampo        = Rp 15000
# Mie Instant   = Rp 5000
# Detergen      = Rp 17500
#
# Total         = Rp 47500
